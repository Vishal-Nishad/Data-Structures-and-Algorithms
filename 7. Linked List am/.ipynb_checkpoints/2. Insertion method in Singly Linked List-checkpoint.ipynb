# %%
# best version, easy and clear to understand
class Node:
    def __init__(self,value = None):
        self.value = value
        self.next = None

class SLList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_at_beginning(self,value):
        new_node = Node(value)
        if self.head is None:
            self.head = self.tail = new_node
            return
        new_node.next = self.head
        self.head = new_node

    def insert_at_end(self,value):
        new_node = Node(value)
        self.tail.next = new_node
        self.tail = new_node

    def insert_at_middle(self,value,position):
        if position == 0:
            return self.insert_at_beginning(value)

        new_node = Node(value)
        index = 0
        temp_node = self.head
        while index < position - 1:
            if temp_node.next is None:
                raise IndexError("Index out of bounds")
            temp_node = temp_node.next
            index += 1
        next_node = temp_node.next
        temp_node.next = new_node
        new_node.next = next_node
# Traverse single linked list
    def traverse_sll(self):
        if self.head is None:
            print("linked list does not exist")
        else:
            node = self.head
            while node:
                print(node.value)
                node = node.next
# Search for a node in singly linked list
    def search_sll(self, node_value):
        if self.head is None:
            print("linked list does not exist")
        else:
            curr = self.head
            while curr:
                if curr.value == node_value:
                    return curr.value
                curr = curr.next
singly_ll = SLList()
singly_ll.insert_at_beginning(1)
singly_ll.insert_at_end(5)
singly_ll.insert_at_beginning(120)
singly_ll.insert_at_middle(10,2)
singly_ll.traverse_sll()
singly_ll.search_sll(10)
# Out:
# 120
# 1
# 10
# 5
# 10

# %%
class Node:
    def __init__(self,value=None):
        self.value = value
        self.next = None

class SLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next

# __iter__ yields Node objects
# .value → actual data inside node
# .next → reference to another Node
    # Insert in Linked List
    def insert_sll(self,value,location):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            if location == 0:       #inserting element in starting/beginning
                new_node.next = self.head
                self.head = new_node
            elif location == 1:  # inserting in last
                new_node.next = None
                self.tail.next = new_node
                self.tail = new_node
            else:
                temp_node = self.head
                index  = 0
                while index < location -1:
                    temp_node = temp_node.next
                    index += 1
                next_node = temp_node.next
                temp_node.next = new_node
                new_node.next = next_node

singly_ll = SLinkedList()
singly_ll.insert_sll(1,1)
singly_ll.insert_sll(2,1)
singly_ll.insert_sll(3,1)
singly_ll.insert_sll(4,1)

print([node.value for node in singly_ll],",     ",[node.next for node in singly_ll])
print(singly_ll.head, singly_ll.tail)

# node1 (head) → 0x7550
# node2        → 0xD710
# node3        → 0xE490
# node4 (tail) → 0xDFD0
# Out:
# [1, 2, 3, 4] ,      [<__main__.Node object at 0x000002AA54F8D710>, <__main__.Node object at 0x000002AA54F8E490>, <__main__.Node object at 0x000002AA54F8DFD0>, None]
# <__main__.Node object at 0x000002AA563F7550> <__main__.Node object at 0x000002AA54F8DFD0>

# %% [markdown]
# This is a **deep but fundamental Python question**, and you’re asking it at exactly the right time.
# I’ll explain it **from first principles**, not linked-list-specific, so it becomes permanent knowledge.
#
# Your core confusion is this:
#
# > ❓ Why does `node.value` print the *actual value*
# > ❓ but `node.next` prints a *reference / memory-looking thing*
# > ❓ how does Python know the difference?
# > ❓ how does *the user* know in advance what will print?
#
# Let’s answer all of that **cleanly and precisely**.
#
# ---
#
# # 🔑 The single most important rule (read this first)
#
# > **Python never prints “values” or “references”.
# > Python prints OBJECTS — using rules based on their TYPE.**
#
# Everything else follows from this.
#
# ---
#
# ## 1️⃣ What is actually stored in `value` and `next`?
#
# Look at your class again:
#
# ```python
# class Node:
#     def __init__(self, value=None):
#         self.value = value
#         self.next = None
# ```
#
# ### This means:
#
# | Attribute | What it stores                        |
# | --------- | ------------------------------------- |
# | `value`   | **an integer object** (e.g. `1`, `2`) |
# | `next`    | **a Node object** OR `None`           |
#
# ⚠️ They are **not the same kind of thing**.
#
# ---
#
# ## 2️⃣ Python treats objects differently based on TYPE
#
# Let’s look at the types:
#
# ```python
# type(node.value)   # int
# type(node.next)    # Node or NoneType
# ```
#
# This single difference explains **everything**.
#
# ---
#
# ## 3️⃣ Why integers print “normally”
#
# When you do:
#
# ```python
# print(1)
# ```
#
# Python internally does something like:
#
# ```python
# print( int.__str__(1) )
# ```
#
# or
#
# ```python
# print( int.__repr__(1) )
# ```
#
# And `int` already defines **how it should look as text**:
#
# ```
# 1
# ```
#
# So when you do:
#
# ```python
# print(node.value)
# ```
#
# Python sees:
#
# * this is an `int`
# * it knows how to represent it
# * it prints the number
#
# ✅ **No confusion here**
#
# ---
#
# ## 4️⃣ Why `node.next` prints a reference-looking thing
#
# Now this:
#
# ```python
# print(node.next)
# ```
#
# But `node.next` is **a Node object**.
#
# Python asks:
#
# > “How should I print this Node?”
#
# Then it checks:
#
# 1. Does `Node` define `__str__`? ❌
# 2. Does `Node` define `__repr__`? ❌
#
# So Python falls back to the **default object representation**:
#
# ```
# <__main__.Node object at 0x000002AA54F8DFD0>
# ```
#
# This means:
#
# * class name
# * memory identity (address-like number)
#
# ⚠️ This is NOT a “reference” being printed
# It is Python’s **default textual description** of an object.
#
# ---
#
# ## 5️⃣ So the REAL difference is THIS
#
# | Attribute | What’s inside | How Python prints it              |
# | --------- | ------------- | --------------------------------- |
# | `value`   | `int` object  | prints number                     |
# | `next`    | `Node` object | prints default object description |
#
# Python does **not** look at variable names.
# It looks only at the **object’s type**.
#
# ---
#
# ## 6️⃣ How does Python decide what to print?
#
# When you do:
#
# ```python
# print(x)
# ```
#
# Python does this internally:
#
# 1. Look at the object `x`
# 2. If `x.__str__()` exists → use it
# 3. Else if `x.__repr__()` exists → use it
# 4. Else → print default `<ClassName object at id>`
#
# That’s it.
#
# ---
#
# ## 7️⃣ How does the USER know what will print?
#
# This is the **developer rule you must memorize**:
#
# > **If an attribute stores a primitive (int, str, float, bool), it prints the value.
# > If it stores an object, Python prints the object’s representation.**
#
# So you can predict output **before running code**.
#
# ---
#
# ## 8️⃣ Example to lock it in (NOT linked list)
#
# ```python
# class Box:
#     def __init__(self, x):
#         self.x = x
#
# b1 = Box(10)
# b2 = Box(b1)
#
# print(b1.x)   # 10
# print(b2.x)   # <__main__.Box object at ...>
# ```
#
# Why?
#
# * `b1.x` → int
# * `b2.x` → Box object
#
# Same rule. No magic.
#
# ---
#
# ## 9️⃣ How to make Node print “value” instead of memory
#
# If you want:
#
# ```python
# print(node)
# ```
#
# to print:
#
# ```
# 1
# ```
#
# You must **teach Python how to print Node**.
#
# Add this:
#
# ```python
# class Node:
#     def __init__(self, value=None):
#         self.value = value
#         self.next = None
#
#     def __repr__(self):
#         return str(self.value)
# ```
#
# Now:
#
# ```python
# print(node.next)
# ```
#
# prints:
#
# ```
# 2
# ```
#
# Because Python now knows **how YOU want Node to look**.
#
# ---
#
# ## 🔥 CRITICAL REALIZATION (THIS ENDS THE CONFUSION)
#
# > **Printing behavior has NOTHING to do with linked lists.
# > It is 100% about object types and `__str__ / __repr__`.**
#
# ---
#
# ## 🧠 Final mental checklist (use this always)
#
# Ask yourself:
#
# 1. What object does this variable point to?
# 2. What is its type?
# 3. Does that type define how it prints?
#
# You’ll always know the output.
#
# ---
#
# ## ✅ Final self-test (important)
#
# 👉 Why does this print numbers?
#
# ```python
# [node.value for node in singly_ll]
# ```
#
# 👉 Why does this print objects?
#
# ```python
# [node.next for node in singly_ll]
# ```
#
# Correct answers:
#
# * `.value` → int
# * `.next` → Node
#
# If that’s clear — **you now fully understand Python object printing**.
#
# ---
#
# If you want next, I can:
# 1️⃣ Explain `__str__` vs `__repr__` properly
# 2️⃣ Show `id()` and memory identity clearly
# 3️⃣ Explain why `None` prints as `None`
# 4️⃣ Show how this matters in debugging
# 5️⃣ Move on to deleting nodes safely
#
# Just tell me the number.

# %% [markdown]
# This is a **very deep and very correct question**.
# You’ve reached the point where most people *stop thinking* — you didn’t. Good.
#
# Your confusion boils down to this:
#
# > ❓ *“In `insert_sll`, I never touch `.value`.
# > I only manipulate `.next`.
# > Then HOW do values stay correct and print correctly?”*
#
# The answer is **the most important Linked List principle**.
# Once you get this, Linked List becomes *boring and mechanical*.
#
# ---
#
# # 🔑 CORE ANSWER (READ THIS FIRST)
#
# > **Values are assigned ONCE when a node is created.
# > After that, insertion logic NEVER touches values —
# > it only rearranges connections between nodes.**
#
# That’s it.
# Now let’s prove it slowly and deeply.
#
# ---
#
# ## 1️⃣ Where is `.value` ACTUALLY assigned?
#
# Look at **only this line**:
#
# ```python
# new_node = Node(value)
# ```
#
# Now open the `Node` class:
#
# ```python
# class Node:
#     def __init__(self, value=None):
#         self.value = value
#         self.next = None
# ```
#
# 👉 **THIS is where the value is stored.**
#
# At that moment:
#
# ```
# new_node ──► Node
#               value = value_you_passed
#               next  = None
# ```
#
# Example:
#
# ```python
# insert_sll(3, 1)
# ```
#
# Creates:
#
# ```
# Node(value=3, next=None)
# ```
#
# ⚠️ **From this point onward, the value is permanently inside the node.**
#
# ---
#
# ## 2️⃣ What does insertion logic ACTUALLY do?
#
# Now look at the rest of your method:
#
# ```python
# new_node.next = self.head
# self.head = new_node
# ```
#
# or
#
# ```python
# self.tail.next = new_node
# self.tail = new_node
# ```
#
# or
#
# ```python
# temp_node.next = new_node
# new_node.next = next_node
# ```
#
# ### Notice something important?
#
# ❌ You never write:
#
# ```python
# new_node.value = ...
# ```
#
# ❌ You never change:
#
# ```python
# existing_node.value
# ```
#
# You are **only moving references**.
#
# ---
#
# ## 3️⃣ Think of Node as a “box”
#
# A Node is like a sealed box:
#
# ```
# ┌──────────────┐
# │ value : 3    │  ← fixed
# │ next  : ???  │  ← changeable
# └──────────────┘
# ```
#
# * `.value` → content of the box
# * `.next` → where the box points
#
# 👉 Insertion logic **moves boxes**, not contents.
#
# ---
#
# ## 4️⃣ Why values remain “perfect”
#
# Because:
#
# * Each value is stored **inside its own Node**
# * You never modify `.value`
# * You only change `.next` pointers
#
# So values stay intact forever.
#
# ---
#
# ## 5️⃣ Why printing works perfectly
#
# When you later do:
#
# ```python
# for node in singly_ll:
#     print(node.value)
# ```
#
# What happens?
#
# 1. `__iter__` yields a **Node object**
# 2. `node.value` accesses the value stored INSIDE that node
# 3. Since it was never changed → it prints correctly
#
# Traversal does NOT compute values.
# It just **visits nodes**.
#
# ---
#
# ## 6️⃣ CRITICAL REALIZATION 🔥🔥🔥
#
# > **Linked List algorithms manipulate structure, NOT data.**
#
# That is the whole game.
#
# ---
#
# ## 7️⃣ Why `.next` is used everywhere but `.value` is not
#
# Because:
#
# | Attribute | Purpose                            |
# | --------- | ---------------------------------- |
# | `.value`  | stores data (set once)             |
# | `.next`   | controls structure (changes often) |
#
# Insertion, deletion, reversal, merge —
# ALL work by changing `.next`.
#
# ---
#
# ## 8️⃣ Example to make it 100% obvious
#
# Imagine this code:
#
# ```python
# n1 = Node(10)
# n2 = Node(20)
#
# n1.next = n2
# n1.next = None
# ```
#
# Question:
# ❓ Did `10` or `20` change?
#
# ❌ No
# Only the connection changed.
#
# ---
#
# ## 9️⃣ This is WHY Linked List questions feel weird at first
#
# In arrays:
#
# ```python
# arr.insert(1, 99)
# ```
#
# You feel like:
#
# > “I inserted a value”
#
# But in linked list:
#
# > You inserted a **node that already has a value**,
# > then re-wired pointers.
#
# ---
#
# ## 🔒 ONE SENTENCE THAT LOCKS EVERYTHING
#
# > **Node creation handles values.
# > List operations handle links.**
#
# Say this in your head when confused.
#
# ---
#
# ## 🧠 Final sanity check (answer honestly)
#
# 👉 If I reverse a linked list, do values change?
#
# ❌ No
# ✅ Only `.next` pointers change
#
# 👉 If I print values after reversal, why are they correct?
#
# ✅ Because values were never touched
#
# ---
#
# ## 🎉 Congratulations
#
# You now understand:
#
# * where data lives
# * why insertion doesn’t touch values
# * why printing works
# * why `.next` is the only thing algorithms care about
#
# This is **the exact mental model interviewers expect**.
#
# ---
#
# ### What do you want next?
#
# 1️⃣ Delete operation (with same deep clarity)
# 2️⃣ Reverse linked list (pointer-only logic)
# 3️⃣ Why head/tail updates matter
# 4️⃣ Convert this to LeetCode problems
# 5️⃣ Common bugs & edge cases
#
# Tell me the number.

# %%
******************************************************************************************************************************************************

# %% [markdown]
# This is an **excellent foundational question**.
# What you’re really asking is:
#
# > “How does `__init__` actually work in Python, and how can one object remember its state (like `size`) correctly across method calls?”
#
# If you understand this, **OOP stops being magic**.
#
# I’ll explain this **from first principles**, slowly, with mental models — no shortcuts.
#
# ---
#
# # 1️⃣ What `__init__` REALLY is (plain English)
#
# `__init__` is **not**:
#
# * a function you call manually
# * a place where Python “stores defaults”
#
# `__init__` is:
#
# > **A special method that runs automatically when a new object is created.**
#
# That’s it.
#
# ---
#
# ## When does `__init__` run?
#
# This line:
#
# ```python
# correct_sll = SingleLLCorrect()
# ```
#
# means two things happen **in order**:
#
# ### Step 1: Python creates a new empty object
#
# ```
# object (SingleLLCorrect)
# ```
#
# ### Step 2: Python immediately calls
#
# ```python
# SingleLLCorrect.__init__(correct_sll)
# ```
#
# 👉 Python passes the **new object itself** as `self`.
#
# ---
#
# # 2️⃣ What is `self` REALLY?
#
# This is the most important part.
#
# ### `self` is:
#
# > **The object that was just created.**
#
# So inside `__init__`:
#
# ```python
# def __init__(self):
#     self.head = None
#     self.tail = None
#     self.size = 0
# ```
#
# Means:
#
# > “Attach these variables to THIS object.”
#
# Memory now looks like:
#
# ```
# correct_sll ──► {
#     head = None
#     tail = None
#     size = 0
# }
# ```
#
# These are called **instance variables**.
#
# ---
#
# # 3️⃣ Why `size` works even though object was created only once
#
# You’re thinking:
#
# > “I created `correct_sll` only one time…
# > then how does `size` keep changing correctly?”
#
# Because:
#
# * `size` lives **inside the object**
# * Methods modify `self.size`
# * The object stays alive as long as the variable refers to it
#
# Every time you do:
#
# ```python
# correct_sll.insertion(...)
# ```
#
# Python internally does:
#
# ```python
# SingleLLCorrect.insertion(correct_sll, ...)
# ```
#
# So:
#
# ```python
# self.size += 1
# ```
#
# means:
#
# ```python
# correct_sll.size += 1
# ```
#
# The value persists.
#
# ---
#
# # 4️⃣ Visual memory model (THIS IS KEY)
#
# After creation:
#
# ```
# correct_sll
#  ├─ head → None
#  ├─ tail → None
#  └─ size → 0
# ```
#
# After first insertion:
#
# ```
# correct_sll
#  ├─ head → Node(1)
#  ├─ tail → Node(1)
#  └─ size → 1
# ```
#
# After second insertion:
#
# ```
# correct_sll
#  ├─ head → Node(1)
#  ├─ tail → Node(2)
#  └─ size → 2
# ```
#
# Nothing resets unless you create a **new object**.
#
# ---
#
# # 5️⃣ What if you create another object?
#
# ```python
# another_sll = SingleLLCorrect()
# ```
#
# This runs `__init__` AGAIN — for a NEW object.
#
# Memory:
#
# ```
# another_sll
#  ├─ head → None
#  ├─ tail → None
#  └─ size → 0
# ```
#
# Two independent objects.
#
# ---
#
# # 6️⃣ Why sometimes `__init__` has parameters and sometimes not
#
# ### Case 1: No parameters
#
# ```python
# def __init__(self):
#     self.size = 0
# ```
#
# Use this when:
#
# * all objects start the same way
# * values will be set later via methods
#
# Your linked list is exactly this case.
#
# ---
#
# ### Case 2: With parameters
#
# ```python
# def __init__(self, value):
#     self.value = value
# ```
#
# Use this when:
#
# * object needs initial data immediately
# * object is incomplete without that data
#
# Example: `Node`
#
# ```python
# node = Node(10)
# ```
#
# A node without a value is meaningless.
#
# ---
#
# ## 🔑 Rule of thumb
#
# > **If an object cannot exist meaningfully without some data → pass it in `__init__`.**
# > **If data can be added later → don’t pass it.**
#
# ---
#
# # 7️⃣ Why we DON’T pass size, head, tail into `__init__`
#
# Imagine this:
#
# ```python
# SingleLLCorrect(head, tail, size)
# ```
#
# That would be:
#
# * confusing
# * unsafe
# * unnecessary
#
# Those are **internal state**, not user input.
#
# ---
#
# # 8️⃣ Very important: `__init__` runs ONLY ONCE per object
#
# It does NOT run:
#
# * when you call methods
# * when you modify attributes
# * on every insertion
#
# It runs:
# ✔ exactly once
# ✔ at object creation
#
# ---
#
# # 9️⃣ Why `__init__` is called “initializer” not “constructor”
#
# In Python:
#
# * object is already created **before** `__init__`
# * `__init__` only **initializes attributes**
#
# That’s why it’s called an *initializer*.
#
# ---
#
# # 🔥 One-sentence mental model (LOCK THIS)
#
# > **`__init__` sets up the starting state of an object;
# > methods change that state over time.**
#
# ---
#
# # 🧠 Final sanity check (answer in your head)
#
# 👉 If I call `insertion()` 10 times, does `__init__` run again?
#
# ❌ No
#
# 👉 If I create a second linked list object, does `__init__` run?
#
# ✅ Yes
#
# 👉 Where does `size` live?
#
# ✅ Inside the object, not inside the class
#
# ---
#
# ## 🎉 Congratulations
#
# You now understand:
#
# * what `__init__` really does
# * why state persists
# * how `self` works
# * when to use parameters in `__init__`
#
# This is **core OOP mastery**, not beginner stuff.
#
# ---
#
# ### Next, I recommend:
#
# * visualizing object memory with diagrams
# * adding `__str__` / `__repr__`
# * implementing delete safely
# * comparing with arrays
# * starting LeetCode Linked List problems
#
# Just tell me what you want next.

# %% [markdown]
# Take a breath 🙂
# What you’re confused about is **the most important conceptual jump in Linked Lists**:
#
# > **“If I keep creating new Node objects every time,
# > how do they stay connected and work as ONE list?”**
#
# This is NOT a silly question.
# This is **the question**.
#
# I’ll explain it **slowly**, **mechanically**, and **with a memory model** so it finally clicks.
#
# ---
#
# # 🔴 First, separate TWO kinds of objects (this is crucial)
#
# There are **two completely different objects** involved:
#
# ## 1️⃣ The Linked List object (ONLY ONE)
#
# ```python
# correct_sll = SingleLLCorrect()
# ```
#
# This object stores:
#
# ```text
# head, tail, size
# ```
#
# Think of it as a **manager / controller**.
#
# ---
#
# ## 2️⃣ Node objects (MANY)
#
# Every time you do:
#
# ```python
# new_node = Node(value)
# ```
#
# You create a **new, independent Node object**.
#
# Each Node has:
#
# ```text
# value, next
# ```
#
# ---
#
# # 🧠 CORE TRUTH (READ THIS CAREFULLY)
#
# > **The Linked List object does NOT store values.**
# > **The Node objects store values.**
# >
# > The Linked List object only stores REFERENCES
# > to the FIRST and LAST Node.
#
# Everything works because of **references**, not magic.
#
# ---
#
# # 1️⃣ What happens when you create the linked list?
#
# ```python
# correct_sll = SingleLLCorrect()
# ```
#
# Python does:
#
# ```python
# SingleLLCorrect.__init__(correct_sll)
# ```
#
# Memory looks like this:
#
# ```
# correct_sll
#  ├─ head → None
#  ├─ tail → None
#  └─ size → 0
# ```
#
# No nodes exist yet.
#
# ---
#
# # 2️⃣ First insertion (VERY IMPORTANT)
#
# ```python
# correct_sll.insertion(1, 0)
# ```
#
# Inside `insertion`:
#
# ```python
# new_node = Node(1)
# ```
#
# This creates a **new Node object**:
#
# ```
# new_node → Node(value=1, next=None)
# ```
#
# Now code does:
#
# ```python
# self.head = new_node
# self.tail = new_node
# ```
#
# Memory becomes:
#
# ```
# correct_sll
#  ├─ head ─────┐
#  ├─ tail ─────┘
#  └─ size = 1
#
# Node(1)
#  ├─ value = 1
#  └─ next = None
# ```
#
# 🔥 IMPORTANT
# There is **ONE node**, and both `head` and `tail` point to it.
#
# ---
#
# # 3️⃣ Second insertion (THIS IS WHERE CONFUSION STARTS)
#
# ```python
# correct_sll.insertion(2, 1)
# ```
#
# Again:
#
# ```python
# new_node = Node(2)
# ```
#
# A **brand new Node object** is created:
#
# ```
# new_node → Node(value=2, next=None)
# ```
#
# Now comes the **connection step**:
#
# ```python
# self.tail.next = new_node
# self.tail = new_node
# ```
#
# Let’s decode this **slowly**.
#
# ---
#
# ## Step 1: `self.tail.next = new_node`
#
# What is `self.tail` pointing to?
#
# ```
# self.tail → Node(1)
# ```
#
# So this line means:
#
# ```
# Node(1).next = Node(2)
# ```
#
# Now memory is:
#
# ```
# Node(1) → Node(2) → None
# ```
#
# ---
#
# ## Step 2: `self.tail = new_node`
#
# Now update the tail reference:
#
# ```
# tail → Node(2)
# ```
#
# Final state:
#
# ```
# correct_sll
#  ├─ head → Node(1)
#  ├─ tail → Node(2)
#  └─ size = 2
#
# Node(1).next → Node(2)
# Node(2).next → None
# ```
#
# 🔥 THIS is the **link** in linked list.
#
# ---
#
# # 4️⃣ Third insertion (pattern repeats)
#
# ```python
# correct_sll.insertion(3, 2)
# ```
#
# New object created:
#
# ```
# Node(3)
# ```
#
# Then:
#
# ```python
# self.tail.next = new_node   # Node(2).next = Node(3)
# self.tail = new_node        # tail → Node(3)
# ```
#
# Now:
#
# ```
# Node(1) → Node(2) → Node(3) → None
# ```
#
# ---
#
# # 5️⃣ IMPORTANT REALIZATION (THIS ENDS CONFUSION)
#
# > **Nodes do NOT know about the Linked List.**
# > **Linked List does NOT store nodes in a container.**
# >
# > Nodes only know the NEXT node.
# > Linked List only knows the FIRST and LAST node.
#
# That’s it.
#
# ---
#
# # 6️⃣ Why creating new Node every time is REQUIRED
#
# You said:
#
# > “But every time we do `Node(value)`, a new object is created…”
#
# YES — **that is exactly what we want**.
#
# Each node is:
#
# * a separate box
# * holding one value
# * holding one pointer
#
# Linked List = **chain of boxes**, not one box.
#
# ---
#
# # 7️⃣ Why values don’t get lost
#
# Because:
#
# * Once a Node object is created, it stays in memory
# * As long as **some variable points to it**, it is alive
# * `head → first node → second node → third node`
#
# So even if `new_node` variable goes out of scope,
# the nodes stay alive because:
#
# ```
# head → Node → Node → Node
# ```
#
# Python garbage-collects objects **only when nothing references them**.
#
# ---
#
# # 8️⃣ Key misunderstanding you had (be honest)
#
# You were unconsciously thinking like an array:
#
# ```python
# list = [1,2,3]
# ```
#
# But Linked List is NOT a container.
#
# It is:
#
# ```
# head → [1] → [2] → [3] → None
# ```
#
# Each `[ ]` is a **separate object**.
#
# ---
#
# # 9️⃣ Why size works correctly
#
# `size` lives **inside the linked list object**, not nodes.
#
# Each time you insert:
#
# ```python
# self.size += 1
# ```
#
# You are modifying:
#
# ```
# correct_sll.size
# ```
#
# Nodes don’t care about size.
#
# ---
#
# # 🔒 ONE SENTENCE THAT LOCKS EVERYTHING
#
# > **Linked List = one manager object + many node objects connected by references.**
#
# Say this until it sticks.
#
# ---
#
# # 🧠 Final sanity check (ANSWER THESE)
#
# 👉 Does `__init__` run when creating a Node?
# ✅ Yes (Node.**init**)
#
# 👉 Does `SingleLLCorrect.__init__` run when inserting?
# ❌ No
#
# 👉 How are nodes connected?
# ✅ By assigning `.next` to point to another node
#
# 👉 Why don’t nodes disappear?
# ✅ Because `head` (indirectly) still references them
#
# ---
#
# ## 🎉 You are NOT bad at this
#
# You were confused because:
#
# * Linked List breaks the “container” mental model
# * It is pointer-based, not value-based
#
# Now you are thinking **correctly**.
#
# ---
#
# ### What I strongly recommend next
#
# We should now:
# 1️⃣ Visually simulate memory with drawings
# 2️⃣ Implement delete (this will cement everything)
# 3️⃣ Reverse linked list (pure pointer logic)
# 4️⃣ Compare array vs linked list internally
#
# Just tell me what you want next.

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class SingleLLCorrect:
    def __init__(self):
# __init__ is:
# A special method that runs automatically when a new object is created.
        self.head = None
        self.tail = None
        self.size = 0
    def insertion(self,value,position):
        if position < 0 or position > self.size:
            raise IndexError("Position out of bounds")
        new_node = Node(value)
        if position == 0:
            if self.head is None:
                self.head = new_node
                self.tail = new_node
            else:
                new_node.next = self.head
                self.head = new_node
        elif position == self.size:
            self.tail.next = new_node
            self.tail = new_node
        else:
            temp_node = self.head
            index = 0
            while index < position -1:
                temp_node = temp_node.next
                index += 1
            new_node.next = temp_node.next
            temp_node.next = new_node
        self.size += 1
correct_sll = SingleLLCorrect()
correct_sll.insertion(1,0)
correct_sll.insertion(2,1)
correct_sll.insertion(3,2)
correct_sll.insertion(4,3)

curr = correct_sll.head
while curr:
    print(curr.value)
    curr = curr.next
# Out:
# 1
# 2
# 3
# 4

# %%
class Node:
    def __init__(self,value= None):
        self.value = value
        self.next = None
class SLL():
    def __init__(self):
        self.head = None
        self.tail = None

    # def __iter__(self):
    #     curr = self.head
    #     while curr:
    #         yield curr
    #         curr = curr.next 

# Linked List values are never printed automatically.
# You must TRAVERSE the list.
    def insertion(self,value,location):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            if location == 0:
                new_node.next = self.head
                self.head = new_node
            elif location == 1:
                self.tail.next = new_node
                self.tail = new_node
            else:
                tempnode = self.head
                index = 1
                while index < location - 1:
                    tempnode = tempnode.next
                    index += 1
                next_node = tempnode.next
                tempnode.next = new_node
                new_node.next = next_node

object_sll = SLL()
object_sll.insertion(1,1)
object_sll.insertion(2,1)
object_sll.insertion(3,1)
object_sll.insertion(4,1)

# print(object_sll.head)          

# “A linked list is printed by starting at head and following .next until None.”
curr = object_sll.head
while curr is not None:
    print(curr.value)
    curr = curr.next
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# First — **relax**.
# What you’re feeling is **normal**, and I’m going to be very direct with you:
#
# > ❌ You are NOT bad at Linked Lists
# > ❌ You are NOT slow
# > ❌ You are NOT missing intelligence
#
# Your problem is **mental model**, not code.
#
# You’re trying to *memorize code* without understanding **who owns what** and **what moves vs what stays fixed**.
#
# We will fix that **permanently** now.
#
# I will do this in **layers**, and I will **repeat the same truth in different ways** until it clicks.
#
# ---
#
# # 🔴 THE ROOT PROBLEM (READ THIS CAREFULLY)
#
# You are mixing up **THREE DIFFERENT THINGS**:
#
# 1. The **LinkedList object**
# 2. The **Node objects**
# 3. The **references (arrows) between them**
#
# Until these are separated in your head, insertion will NEVER stick.
#
# So let’s reset.
#
# ---
#
# # 1️⃣ What the TWO CLASSES ACTUALLY MEAN (NO CODE)
#
# ## 🔹 Node class
#
# A `Node` is a **box** that contains:
#
# * one **value**
# * one **arrow to another box**
#
# That’s it.
#
# ```
# ┌──────────────┐
# │ value = 10   │
# │ next  = ???  │───► another Node or None
# └──────────────┘
# ```
#
# ---
#
# ## 🔹 SinglyLinkedList class
#
# A `SinglyLinkedList` is **NOT a list of values**.
#
# It is ONLY a **manager** that remembers:
#
# * where the list **starts**
# * where the list **ends**
#
# ```
# LinkedList
#  ├─ head ───► Node
#  └─ tail ───► Node
# ```
#
# ⚠️ **IMPORTANT**
# The LinkedList does **NOT** store elements.
# Nodes store elements.
#
# ---
#
# # 2️⃣ Now answer your FIRST BIG CONFUSION
#
# > ❓ “If list is empty, why do we set BOTH head and tail?”
#
# ```python
# if self.head is None:
#     self.head = new_node
#     self.tail = new_node
# ```
#
# ### This is NOT optional. This is REQUIRED.
#
# ### WHY?
#
# Because when the list has **ONE node**:
#
# ```
# head → [10] → None
# tail ───────^
# ```
#
# 📌 Head and tail must point to the **same node**.
#
# If you did this instead:
#
# ```python
# self.head = new_node
# self.tail = None
# ```
#
# Then:
#
# * You have **no idea where the last node is**
# * Appending later will break
#
# 👉 **A list with one node still has a tail**.
#
# ---
#
# ## 🔑 RULE (MEMORIZE THIS)
#
# > **If the list has exactly ONE node,
# > head and tail MUST point to the same node.**
#
# ---
#
# # 3️⃣ SECOND BIG CONFUSION:
#
# ## “How can `tail.next` exist if tail is in LinkedList and next is in Node?”
#
# This is the MOST IMPORTANT clarification.
#
# ---
#
# ## 🔴 WRONG THINKING (what your brain is doing)
#
# > “tail is part of LinkedList
# > next is part of Node
# > how can they talk?”
#
# ---
#
# ## ✅ CORRECT THINKING (THIS IS THE FIX)
#
# > **`tail` does NOT store a value**
# > **`tail` stores a REFERENCE to a Node**
#
# So this line:
#
# ```python
# self.tail = new_node
# ```
#
# Means:
#
# ```
# tail ──► Node(value, next)
# ```
#
# Once `tail` points to a Node, you can do:
#
# ```python
# self.tail.next
# ```
#
# Because you are actually doing:
#
# ```python
# (node object).next
# ```
#
# ---
#
# ### Think of it like this (VERY IMPORTANT)
#
# ```python
# person.phone = phone_object
# person.phone.number
# ```
#
# * `person` is NOT a Phone
# * but `person.phone` points to a Phone
# * so `.number` works
#
# Same logic.
#
# ---
#
# # 4️⃣ Now your BIGGEST CONFUSION (THIS ONE)
#
# You said:
#
# > “We wrote `new_node.next = None`,
# > then how does `self.tail.next = new_node` work?”
#
# This is CRITICAL. Read slowly.
#
# ---
#
# ## THESE TWO LINES ARE ON **DIFFERENT OBJECTS**
#
# ```python
# new_node.next = None
# self.tail.next = new_node
# ```
#
# They do **NOT** touch the same thing.
#
# ### At that moment:
#
# * `new_node.next` → next of **new node**
# * `self.tail.next` → next of **old tail**
#
# You are confusing **which node** `.next` belongs to.
#
# ---
#
# # 5️⃣ LET’S DO A FULL DRY RUN (NO SKIPPING)
#
# ### Start with EMPTY LIST
#
# ```
# head = None
# tail = None
# ```
#
# ---
#
# ### Insert 10 at end
#
# ```python
# new_node = Node(10)
# ```
#
# ```
# new_node → [10 | None]
# ```
#
# Since list is empty:
#
# ```python
# self.head = new_node
# self.tail = new_node
# ```
#
# ```
# head → [10] → None
# tail ───────^
# ```
#
# ---
#
# ### Insert 20 at end
#
# ```python
# new_node = Node(20)
# ```
#
# ```
# new_node → [20 | None]
# ```
#
# Now list is NOT empty, so:
#
# ```python
# self.tail.next = new_node
# ```
#
# What does this mean?
#
# ```
# old tail → [10 | None]
# ```
#
# Becomes:
#
# ```
# [10 | ───► new_node]
# ```
#
# Now update tail:
#
# ```python
# self.tail = new_node
# ```
#
# Final structure:
#
# ```
# head → [10] → [20] → None
# tail ─────────────^
# ```
#
# 🔥 NOTHING MAGIC HAPPENED
# 🔥 Only arrows changed
#
# ---
#
# # 6️⃣ WHY INSERTION IS HARD TO REMEMBER
#
# Because you’re trying to remember **steps**, not **rules**.
#
# ---
#
# # 7️⃣ THE ONLY 3 RULES YOU NEED (WRITE THESE)
#
# ## RULE 1: Node creation
#
# ```python
# new_node = Node(value)
# ```
#
# ➡ value stored FOREVER inside node
#
# ---
#
# ## RULE 2: First node
#
# ```python
# head = new_node
# tail = new_node
# ```
#
# ---
#
# ## RULE 3: Append
#
# ```python
# tail.next = new_node
# tail = new_node
# ```
#
# That’s it.
#
# Everything else is variation.
#
# ---
#
# # 8️⃣ WHY LOCATION-BASED INSERT CONFUSES YOU
#
# Because `location` mixes **two meanings**:
#
# * `0` → beginning
# * `1` → end
# * else → middle
#
# This is BAD design for learning.
#
# Better mental model:
#
# ```python
# insert_at_beginning()
# insert_at_end()
# insert_at_position(pos)
# ```
#
# ---
#
# # 9️⃣ THE REAL REASON YOU “CAN’T WRITE IT AGAIN”
#
# You’re thinking:
#
# > “Which line comes next?”
#
# Instead think:
#
# > “Which arrow must change?”
#
# Linked List problems are **arrow problems**, not value problems.
#
# ---
#
# # 🔒 FINAL MENTAL MODEL (THIS IS THE KEY)
#
# Say this slowly:
#
# > “LinkedList stores head and tail.
# > Nodes store value and next.
# > Insertion never touches value.
# > It only redirects next pointers.”
#
# ---
#
# # 🧠 FINAL CHECK (ANSWER HONESTLY)
#
# 👉 If I remove this line, what breaks?
#
# ```python
# self.tail = new_node
# ```
#
# Answer:
# ❌ You lose track of the last node
# ❌ Next append fails
#
# If you understand THAT — you are 90% done.
#
# ---
#
# ## What I recommend NEXT (VERY IMPORTANT)
#
# We should:
# 1️⃣ **Delete this location-based insert**
# 2️⃣ Write **three simple functions**:
#
# * insert_at_start
# * insert_at_end
# * insert_at_position
#   3️⃣ Draw arrows for each
#
# If you want, say **“YES, rebuild from scratch”**
# and I will rebuild Linked List with you like a whiteboard session.
#
# You are very close.

# %% [markdown]
# You are thinking:
# “I can always find the last node”
#
# Yes — but linked list design is about avoiding repeated traversal.
#
# This is why LinkedList has:
# - head → fast access to start
# - tail → fast access to end
