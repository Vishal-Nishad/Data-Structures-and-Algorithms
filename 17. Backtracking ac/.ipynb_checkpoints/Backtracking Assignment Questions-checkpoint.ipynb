# %% [markdown]
# # Q. Rat in Maze Problem

# %% [markdown]
# STAGE 1
# Only:
# Down + Right
# One path
#
# Understand:
# how TRUE propagates upward
#
# STAGE 2
# Then:
# Down + Right
# All paths
#
# STAGE 3
# Then:
# UDLR
# One path
# Need visited.
#
# STAGE 4
# Finally:
# UDLR
# All paths
#
# This becomes the complete backtracking version.
