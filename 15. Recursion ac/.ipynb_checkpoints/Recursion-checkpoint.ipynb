# %% [markdown]
# # Recursion
# - Recursion is a method of solving a computational problem where the solution depends on solutions to smaller instances of the same problem.
#
# ## Steps to solve recursion problems
# - Base Case
# - What work we have to do
# - arguments or how we gonna call our inner function to solve problems in part

# %% [markdown]
# # Q 1. Print number from n to 1

# %%
def rec_print_no(n):
    if n==0:
        return
    print(n,end=" ")
    rec_print_no(n-1)

rec_print_no(5)
# Out:
# 5 4 3 2 1

# %%
# 1 to n
def rec_print_no(n):
    if n==0:
        return
    rec_print_no(n-1)
    print(n,end=" ")

rec_print_no(5)
# Out:
# 1 2 3 4 5

# %% [markdown]
# # Q 2. factorial of number n

# %%
def fact_rec(n):
    if(n==1):
        return 1
    prev_fact = fact_rec(n-1)
    return n*prev_fact  # n * fact_rec(n-1)
fact_rec(5)
# Out:
# 120

# %% [markdown]
# # Q 3. print sum of first n natural numbers

# %%
def rec_sum_n(n):
    if(n==1):
        return 1
    return n + rec_sum_n(n-1)
rec_sum_n(5)
# Out:
# 15

# %%
def rec_sum_n(n):
    if(n==1):
        return 1
    prev_sum = rec_sum_n(n-1)
    total_sum = n + prev_sum
    return total_sum

rec_sum_n(5)
# Out:
# 15

# %% [markdown]
# # Q 4. print nth fibonacci number

# %%
def fib_iterative(n):
    if(n==1 or n==2):
        return 1
    a = 0
    b = 1
    for i in range(1,n):
        c = a+b
        a = b
        b = c
    return b
fib_iterative(5)
# Out:
# 5

# %%
def rec_fib(n):
    if(n==1 or n==2):
        return 1
    return rec_fib(n-1)+rec_fib(n-2)
rec_fib(10)
# Out:
# 55

# %%
def rec_fib(n):
    if(n==1 or n==2):
        return 1
    fib1 = rec_fib(n-1)
    fib2 = rec_fib(n-2)
    fib_sum = fib1 + fib2
    return fib_sum
rec_fib(10)
# Out:
# 55

# %% [markdown]
# # Q 5. Check if array is sorted or not

# %%
def rec_is_sorted(arr,i):
    if(i == len(arr)-1):
        return True
    if(arr[i]>arr[i+1]):
        return False
    return rec_is_sorted(arr,i+1)

a = [1,4,2,3]
rec_is_sorted(a,0)
# Out:
# False

# %% [markdown]
# # Q 6. find first occurence of given key return its index

# %%
def rec_first_occ(arr,key,i):
    if(i == len(arr)):
        return -1
    if(arr[i] == key):
        return i
    return rec_first_occ(arr,key,i+1)

a = [1,3,2,3]
rec_first_occ(a,5,0)
# Out:
# -1

# %% [markdown]
# # Q 7. find last occurence of given key return its index

# %%
def rec_first_occ(arr,key,i):
    if(i == -1):
        return -1
    if(arr[i] == key):
        return i
    return rec_first_occ(arr,key,i-1)

a = [1,3,2,3]
rec_first_occ(a,3,len(a)-1)
# Out:
# 3

# %%
# another 
def rec_last_occ(arr,key,i):
    if(i == len(arr)):
        return -1
    is_found = rec_last_occ(arr,key,i+1)
    if(is_found == -1 and arr[i] == key):
        return i
    return is_found

a = [1,3,2,3]
rec_last_occ(a,3,0)
# Out:
# 3

# %% [markdown]
# # Q 8. Print x to the power n

# %%
def rec_x_pow_n(x,n):
    if(n==0):
        return 1
    call_value = rec_x_pow_n(x,n-1)
    ans = x * call_value
    return ans
rec_x_pow_n(2,5)
# Out:
# 32

# %%
def rec_x_pow_n(x,n):
    if(n==0):
        return 1
    return x * rec_x_pow_n(x,n-1)
rec_x_pow_n(2,5)
# Out:
# 32

# %%
# optimize, logn
def rec_x_pow_n(x,n):
    if(n==0):
        return 1
    halfpower = rec_x_pow_n(x,n//2)
    halfpower = halfpower * halfpower
    if(n%2 != 0):
        halfpower = x * halfpower
    return halfpower

rec_x_pow_n(2,10)
# Out:
# 1024

# %% [markdown]
# # Q 9. Tiling problem

# %%
def rec_tiling_problem(n): # 2*n floor size ,,, and 2*1 tile size
    if(n==0 or n==1):
        return 1
    # work we have to do
    # vertical choice
    vertical = rec_tiling_problem(n-1)

    # horizontal choice
    horizontal = rec_tiling_problem(n-2)

    total_ways = horizontal + vertical 
    return total_ways

rec_tiling_problem(4)
# Out:
# 5

# %%
print("a"-"a")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("a"-"a")
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# # Q 10. Remove duplicates in a string

# %%
def rec_remove_dup(str,new_str,i,arr):
    if(i==len(str)):
        print(new_str)
        return new_str
    if not (arr[ord(str[i])-97]):
        new_str += str[i]
        arr[ord(str[i])-97] = True
    return rec_remove_dup(str,new_str,i+1,arr)

st = "viisshal"
new_st = ""
arr = [False]*26
rec_remove_dup(st,new_st,0,arr)
# Out:
# vishal
# 'vishal'

# %% [markdown]
# # Q 11. Friends Pairing Problem
# - Given n friends, each one can remain single or can be paired up with some other friend. Each friend can be paired only once. Find out the total number of ways in which friends can remain single or can be paired up.

# %%
def friends_pairing(n):
    if(n==1 or n==2):
        return n
    single_choice = friends_pairing(n-1)
    pair_choice = friends_pairing(n-2)
    total_ways = single_choice + (n-1)*pair_choice
    return total_ways
friends_pairing(4)
# Out:
# 10
