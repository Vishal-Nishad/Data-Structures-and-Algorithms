# %% [markdown]
# 1. **https://leetcode.com/problems/convert-sorted-array-to-binary-search-tree/**

# %%
# using in order traversal property to build bst from sorted array

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def sortedArrayToBST(self, nums: List[int]) -> Optional[TreeNode]:
        def dfs(st,en):
            if st>en:
                return None
            mid = (st+en)//2
            root = TreeNode(nums[mid])
            root.left = dfs(st,mid-1)
            root.right = dfs(mid+1,en)
            return root
        return dfs(0,len(nums)-1)

# %% [markdown]
# 2. **https://leetcode.com/problems/balance-a-binary-search-tree/description/**

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def balanceBST(self, root: Optional[TreeNode]) -> Optional[TreeNode]:
        sorted_arr = []
        
        def buildArr(root):
            if root is None:
                return
            buildArr(root.left)
            sorted_arr.append(root.val)
            buildArr(root.right)

        def dfs(st,end):
            if st > end:
                return None
            mid = (st+end)//2
            root = TreeNode(sorted_arr[mid])
            root.left = dfs(st,mid-1)
            root.right = dfs(mid+1,end)
            return root
        buildArr(root)
        return dfs(0,len(sorted_arr)-1)

# %% [markdown]
# 🔴 3. **https://www.geeksforgeeks.org/problems/largest-bst/1**

# %%
# brute force
# time = O(n2)
# space = O(h)

''' Structure of a Tree Node
class Node:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None
'''
class Solution:
    def largestBst(self, root):
        # Your code here
        def countNodes(root):
            if root is None:
                return 0
            l = countNodes(root.left)
            r = countNodes(root.right)
            return l+r+1
        
        def isBST(root,low,high):
            if root is None:
                return True
            if root.data <= low or root.data >= high:
                return False
            return (isBST(root.left,low,root.data) and isBST(root.right, root.data, high))
        
        answer = 0
        def dfs(root):
            nonlocal answer
            if root is None:
                return
            if isBST(root, float("-inf"), float("inf")):
                answer = max(answer,countNodes(root))
            dfs(root.left)
            dfs(root.right)
        dfs(root)
        return answer

# %%
#optimal 
# time = O(n)
# space = O(h)

''' Structure of a Tree Node
class Node:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None
'''
class Solution:
    def largestBst(self, root):
        # Your code here
        def dfs(root):
            if(root is None):
                return (
                    True,
                    float("inf"),
                    float("-inf"),
                    0
                    )
            leftBST, leftmin, leftmax, leftsize = dfs(root.left)
            rightBST, rightmin, rightmax, rightsize = dfs(root.right)
            
            if(leftBST and rightBST and leftmax < root.data < rightmin):
                currmin = min(leftmin,root.data)
                currmax = max(rightmax,root.data)
                currsize = leftsize + rightsize + 1
                return (
                    True,
                    currmin,
                    currmax,
                    currsize
                    )
            else:
                return(
                    False,
                    float("-inf"),
                    float("inf"),
                    max(leftsize,rightsize)
                    )
        answer = dfs(root)
        return answer[3]

# %% [markdown]
# 4. **https://leetcode.com/problems/maximum-sum-bst-in-binary-tree/description/**

# %%
# todo

# %% [markdown]
# 5. **https://www.geeksforgeeks.org/problems/merge-two-bst-s/1**

# %%
'''
class Node:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None
'''

class Solution:
    def merge(self, root1, root2):
        # code here
        arr1 = []
        arr2 = []
        ans = []
        def dfs(root,arr):
            if(root is None):
                return 
            dfs(root.left,arr)
            arr.append(root.data)
            dfs(root.right,arr)
        dfs(root1,arr1)
        dfs(root2,arr2)
        
        i = 0
        j = 0
        while i <len(arr1) and j <len(arr2):
            if arr1[i] <= arr2[j]:
                ans.append(arr1[i])
                i += 1
            else:
                ans.append(arr2[j])
                j += 1
        while i<len(arr1):
            ans.append(arr1[i])
            i += 1
        while j<len(arr2):
            ans.append(arr2[j])
            j += 1
        return ans
