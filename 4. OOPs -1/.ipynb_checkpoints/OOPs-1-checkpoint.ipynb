# %%
class Student:
    pass

s1=Student()
s2=Student()
s3=Student()
l=list()

# %%
s1.name="vishal"

# %%
s2.roll_no=1
s3.name="rahul"
s3.roll_no=2

# %%
s1.name
# Out:
# 'vishal'

# %%
s1.__dict__
# Out:
# {'name': 'vishal'}

# %%
s3.__dict__
# Out:
# {'name': 'rahul', 'roll_no': 2}

# %%
hasattr(s1, "name")
# Out:
# True

# %%
hasattr(s1, 'roll_no')
# Out:
# False
