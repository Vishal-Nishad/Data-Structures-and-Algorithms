# %% [markdown]
# ## Binary Search

# %%
def bin_search(list,item):
    low=0
    high=len(list)-1
    while low<=high:
        mid=(low+high)//2
        if list[mid]==item:
            return mid
        if list[mid]>item:
            high=mid-1
        if list[mid]<item:
            low=mid+1
        else:
            return "item not found."

l1=[4,5,2343,65,12323,1,3,44]
l1.sort()
bin_search(l1,12)
# Out:
# 'item not found.'
