# %% [markdown]
# # Scenario:
# - You are tasked with determining whether a binary tree is symmetric or transforming it into its mirror image.
#
# # Clue:
# - Look for problems where you compare the left and right subtrees recursively or swap the left and right children to achieve symmetry.

# %% [markdown]
# 1. **https://leetcode.com/problems/invert-binary-tree/description/**

# %%
# worst solution never do, as unwanted memory and time is taking, just to understand deepcopy have a look

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def invertTree(self, root: Optional[TreeNode]) -> Optional[TreeNode]:
        if root is None:
            return root
        
        node = deepcopy(root)
        root.left = self.invertTree(node.right)
        root.right = self.invertTree(node.left)

        # root.left = right
        # root.right = left
        # return node   #can't return node, as it is not the root that we are modifying
        return root  # this will work, as it is modified root

# %%
# this is the optimal copying references first and then using it to modifying original root

# time: O(n)
# space: O(h)

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def invertTree(self, root: Optional[TreeNode]) -> Optional[TreeNode]:
        if root is None:
            return root
        
        left = root.left
        right = root.right
        root.left = self.invertTree(right)
        root.right = self.invertTree(left)
        return root

# %% [markdown]
# 2. **https://leetcode.com/problems/symmetric-tree/description/**

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isSymmetric(self, root: Optional[TreeNode]) -> bool:
        if(root is None):
            return True
        return self.is_mirror(root.left,root.right)
    def is_mirror(self,left,right):
        if(left is None and right is None):
            return True
        if(left is None or right is None):
            return False
        if(left.val != right.val):
            return False
        return (self.is_mirror(left.left,right.right) and self.is_mirror(left.right,right.left))
        # return is_mirror(root.left,root.right)

# %% [markdown]
# 3. **https://leetcode.com/problems/same-tree/submissions/2053894361/**

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def is_same(self,p,q):
        if(p is None and q is None):
            return True
        if(p is None or q is None):
            return False
        if(p.val != q.val):
            return False
        return (self.is_same(p.left,q.left) and self.is_same(p.right,q.right))
    def isSameTree(self, p: Optional[TreeNode], q: Optional[TreeNode]) -> bool:
        if(p is None and q is None):
            return True
        return self.is_same(p,q)
