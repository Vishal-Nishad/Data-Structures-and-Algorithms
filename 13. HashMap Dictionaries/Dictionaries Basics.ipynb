# %%
a = {1:2, 3:4, "list": [1,23], "dict":{1:2}}

# %%
a
# Out:
# {1: 2, 3: 4, 'list': [1, 23], 'dict': {1: 2}}

# %%
# if the key is not present then it will raise an error
a["li"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a["li"]
#
# KeyError: 'li'

# %%
a["list"]
# Out:
# [1, 23]

# %%
# get function does not give error if the key does not present in the dict, infact it take parameter which we want if key 
# does not present in the dict
print(a.get("li"))
# Out:
# None

# %%
# if the key is present then here it will return its associated value, if key is not present then it will return the default value
# which we will pass in get function
a.get("li",0)
# Out:
# 0

# %%
a.values()
# Out:
# dict_values([2, 4, [1, 23], {1: 2}])

# %%
a.items()
# Out:
# dict_items([(1, 2), (3, 4), ('list', [1, 23]), ('dict', {1: 2})])

# %%
a.keys()
# Out:
# dict_keys([1, 3, 'list', 'dict'])

# %%
for i in a:
    print(i, "= ",a[i])
# Out:
# 1 =  2
# 3 =  4
# list =  [1, 23]
# dict =  {1: 2}

# %%
for i in a.values():
    print(i)
# Out:
# 2
# 4
# [1, 23]
# {1: 2}

# %%
"list" in a
# Out:
# True

# %%
5 in a
# Out:
# False

# %% [markdown]
# # Adding or removing Data in Dictionaries

# %%
a
# Out:
# {1: 2, 3: 4, 'list': [1, 23], 'dict': {1: 2}}

# %%
a["tuple"] = (1,2,3)
a
# Out:
# {1: 2, 3: 4, 'list': [1, 23], 'dict': {1: 2}, 'tuple': (1, 2, 3)}

# %%
b = {3:5, "the":4, 2:100}
a.update(b)
a
# Out:
# {1: 2,
#  3: 5,
#  'list': [1, 23],
#  'dict': {1: 2},
#  'tuple': (1, 2, 3),
#  'the': 4,
#  2: 100}

# %%
# to delete any key from dict
a.pop(2)
# Out:
# 100

# %%
a
# Out:
# {1: 2, 3: 5, 'list': [1, 23], 'dict': {1: 2}, 'tuple': (1, 2, 3), 'the': 4}

# %%
del a[1]

# %%
a
# Out:
# {3: 5, 'list': [1, 23], 'dict': {1: 2}, 'tuple': (1, 2, 3), 'the': 4}

# %%
a.clear()

# %%
a
# Out:
# {}

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined
